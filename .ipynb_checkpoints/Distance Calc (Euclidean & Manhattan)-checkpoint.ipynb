# %%
#https://docs.scipy.org/doc/scipy/reference/spatial.distance.html
from scipy.spatial import *

# %% [markdown]
# <img src="Anexos/DistancesCalc.jpg" width="600" height="400">

# %% [markdown]
# <img src="Anexos/MinkovskiDistance.jpeg" width="575" height="400">

# %%
#Import Libs
import pandas as pd

# %%
#Path Definition
path = 'D:/Google Drive/Github/Evaluation-of-Perceptual-Hash-Algorithms/Dados/'

# %%
#Database Name Definition
database = 'mountaindatabase'

# %%
#Full Path Definition
full_path = path + database + ".csv"

# %%
#Database Reading
df = pd.read_csv(full_path, delimiter=";", encoding= 'unicode_escape', engine='python');

# %%
df
# Out:
#      Images Database  A. Hash Hamming  P. Hash Hamming  D. Hash Hamming  \
# 0    Imagem Original                0                0                0
# 1    Alternative (1)                0                2                2
# 2    Alternative (2)                0                2                1
# 3    Alternative (3)                0                2                1
# 4    Alternative (4)                0                2                2
# 5    Alternative (5)                0                2                1
# 6    Alternative (6)                0                2                1
# 7    Alternative (7)                0                2                2
# 8    Alternative (8)                0                2                2
# 9    Alternative (9)                0                2                1
# 10  Alternative (10)                0                2                1
# 11  Alternative (11)                0                2                1
# 12  Alternative (12)                0                2                1
# 13  Alternative (13)                0                0                1
# 14  Alternative (14)                0                2                0
# 15  Alternative (15)                0                2                2
# 16  Alternative (16)                4                6                3
# 17  Alternative (17)                4                8                4
# 18  Alternative (18)                2                8                4
# 19  Alternative (19)                2                6                5
# 20  Alternative (20)                1                8                4
# 21  Alternative (21)                3                8                2
# 22  Alternative (22)                1                6                5
# 23  Alternative (23)                0                2                2
# 24  Alternative (24)                0                2                1
# 25  Alternative (25)                0                2                1
# 26  Alternative (26)                0                2                1
# 27  Alternative (27)                0                2                1
# 28  Alternative (28)                0                2                1
# 29  Alternative (29)                0                2                1
#
#     W. Hash Hamming  Hsv-Color Hamming  CP Hash Hamming
# 0                 0                  0             0.00
# 1                 2                  6            14.16
# 2                 2                  5            15.16
# 3                 2                  5            14.66
# 4                 2                  5            15.16
# 5                 2                  4            15.16
# 6                 2                  6            14.66
# 7                 2                  4            15.16
# 8                 4                  4            15.16
# 9                 4                  5            15.16
# 10                2                  4            15.16
# 11                2                  5            15.16
# 12                2                  5            15.16
# 13                4                  5            15.16
# 14                2                  5            15.16
# 15                4                  5            15.16
# 16                6                  5            15.50
# 17                6                  4            15.16
# 18                6                  7            14.66
# 19                6                  4            15.16
# 20                6                  5            15.33
# 21                6                  5            15.33
# 22                6                  4            15.16
# 23                2                  4            15.16
# 24                2                  2            15.16
# 25                2                  5            15.16
# 26                0                  5            15.66
# 27                2                  5            15.16
# 28                2                  5            15.16
# 29                2                  3            15.16

# %%
#Select All the Values to the Variables
ahash = df['A. Hash Hamming']
phash = df['P. Hash Hamming']
dhash = df['D. Hash Hamming']
whash = df['W. Hash Hamming']
hsvchash = df['Hsv-Color Hamming']
cphash = df['CP Hash Hamming']

# %%
#Total of Images in Databases

total = int(input("Total of Images in Database (Included the Original): "))
Original_array = []

for i in range(total):
    Original_array.append(0)
# Out:
# Total of Images in Database (Included the Original): 30

# %%
#Function to Calc: Euclidean Distance and Manhattan Distance
def distance_Calc(array,algorithm): 
    dst_euclid = distance.euclidean(Original_array, array)
    dst_manh = distance.cityblock(Original_array, array)
    
    print("\nAlgoritmo: " + str(algorithm))
    print("O Valor da Distância Euclidiana é: " + str(dst_euclid))
    print("O valor da Distância de Manhattan é: " + str(dst_manh))

# %%
#Results for All Distances
distance_Calc(ahash, "Average Hashing")
distance_Calc(phash, "Perceptual Hashing")
distance_Calc(dhash, "Difference Hashing")
distance_Calc(whash, "Wavelet Hashing")
distance_Calc(hsvchash, "HSV-Color Hashing")
distance_Calc(cphash, "Crop-Resistant Hashing")
# Out:
# Algoritmo: Average Hashing
# O Valor da Distância Euclidiana é: 7.14142842854285
# O valor da Distância de Manhattan é: 17
#
# Algoritmo: Perceptual Hashing
# O Valor da Distância Euclidiana é: 21.166010488516726
# O valor da Distância de Manhattan é: 92
#
# Algoritmo: Difference Hashing
# O Valor da Distância Euclidiana é: 12.24744871391589
# O valor da Distância de Manhattan é: 54
#
# Algoritmo: Wavelet Hashing
# O Valor da Distância Euclidiana é: 19.595917942265423
# O valor da Distância de Manhattan é: 92
#
# Algoritmo: HSV-Color Hashing
# O Valor da Distância Euclidiana é: 25.729360660537214
# O valor da Distância de Manhattan é: 136
#
# Algoritmo: Crop-Resistant Hashing
# O Valor da Distância Euclidiana é: 81.40696161877067
# O valor da Distância de Manhattan é: 438.32000000000016

# %%
#Example with Minkovski
#1 point = Manhattan; 2 points = Euclidian

dst_mink1= distance.minkowski(Original_array, ahash, 1)
dst_mink2= distance.minkowski(Original_array, ahash, 2)

# %%
#Show the Results
print(dst_mink1)
print(dst_mink2)
# Out:
# 17.0
# 7.14142842854285
