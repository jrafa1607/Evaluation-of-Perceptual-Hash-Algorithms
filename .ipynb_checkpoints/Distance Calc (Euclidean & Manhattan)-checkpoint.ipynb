# %%
#https://docs.scipy.org/doc/scipy/reference/spatial.distance.html
from scipy.spatial import *
import pandas as pd

# %%
#Path Definition
path = 'D:/Google Drive/Github/Evaluation-of-Perceptual-Hash-Algorithms/Data/'

# %%
#Database Definition
database = 'lennadatabase'

# %%
#All the Database
'''
lennadatabase
mountaindatabase
palacedatabase
parkdatabase
washingtondatabase
''';

# %%
#Full Database Path Definition
full_path = path + database + ".csv"

# %%
#Database Reading
df = pd.read_csv(full_path, delimiter=";", encoding= 'unicode_escape', engine='python');

# %%
#Show the Dataframe
df
# Out:
#          Images Database  A. Hash Hamming  P. Hash Hamming  D. Hash Hamming  \
# 0        Imagem Original                0                0                0
# 1          Imagem em Bmp                0                0                0
# 2          Imagem em Png                0                0                0
# 3         Imagem em Tiff                0                0                0
# 4          Gaussiana 3x3                0                0                0
# 5          Gaussiana 7x7                0                0                0
# 6            Mediana 7x7                0                0                0
# 7            Mediana 3x3                0                0                0
# 8              Média 3x3                0                0                0
# 9              Média 7x7                0                0                0
# 10       Pouca alteração                1                0                0
# 11       Adição de Texto                3                2                0
# 12       Escala de Cinza                0                0                0
# 13   Ruído Sal e Pimenta                0                0                1
# 14    Bordas Enfatizadas                0                0                2
# 15       Muita alteração               10                8                2
# 16  Binarização com OTSU                7               10                5
# 17       Metade Alterada               14               10                8
# 18        Efeito Espelho               14               16               14
# 19     Adição de Objetos                7                6                5
#
#     W. Hash Hamming  CP Hash Hamming
# 0                 0             0.00
# 1                 0             0.50
# 2                 0             0.50
# 3                 0             0.50
# 4                 0             0.88
# 5                 0             1.13
# 6                 0             1.25
# 7                 0             1.50
# 8                 0             2.88
# 9                 0             2.88
# 10                0             0.88
# 11                0             0.63
# 12                0             0.50
# 13                2            13.63
# 14                0            12.00
# 15                6            12.88
# 16                5            13.13
# 17               14            14.50
# 18               14            14.75
# 19                6            15.00

# %%
#Select All the Values to the Variables
ahash = df['A. Hash Hamming']
phash = df['P. Hash Hamming']
dhash = df['D. Hash Hamming']
whash = df['W. Hash Hamming']
cphash = df['CP Hash Hamming']

# %%
#Total of Images in Databases
total = int(input("Total of Images in Database (Included the Original): "))
Original_array = []

for i in range(total):
    Original_array.append(0)
# Out:
# Total of Images in Database (Included the Original): 20

# %%
#Function to Calc: Euclidean Distance and Manhattan Distance
def distance_Calc(array,algorithm): 
    dst_euclid = distance.euclidean(Original_array, array)
    dst_manh = distance.cityblock(Original_array, array)
    
    print("\nAlgoritmo: " + str(algorithm))
    print("O Valor da Distância Euclidiana é: " + str(dst_euclid))
    print("O valor da Distância de Manhattan é: " + str(dst_manh))

# %%
#Results for All Distances
distance_Calc(ahash, "Average Hashing")
distance_Calc(phash, "Perceptual Hashing")
distance_Calc(dhash, "Difference Hashing")
distance_Calc(whash, "Wavelet Hashing")
distance_Calc(cphash, "Crop-Resistant Hashing")
# Out:
# Algoritmo: Average Hashing
# O Valor da Distância Euclidiana é: 24.49489742783178
# O valor da Distância de Manhattan é: 56
#
# Algoritmo: Perceptual Hashing
# O Valor da Distância Euclidiana é: 23.664319132398465
# O valor da Distância de Manhattan é: 52
#
# Algoritmo: Difference Hashing
# O Valor da Distância Euclidiana é: 17.86057109949175
# O valor da Distância de Manhattan é: 37
#
# Algoritmo: Wavelet Hashing
# O Valor da Distância Euclidiana é: 22.20360331117452
# O valor da Distância de Manhattan é: 47
#
# Algoritmo: Crop-Resistant Hashing
# O Valor da Distância Euclidiana é: 36.681120484521735
# O valor da Distância de Manhattan é: 109.92

# %%
#Example with Minkovski
#1 point = Manhattan; 2 points = Euclidian

dst_mink1= distance.minkowski(Original_array, ahash, 1)
dst_mink2= distance.minkowski(Original_array, ahash, 2)

print(dst_mink1)
print(dst_mink2)
# Out:
# 56.0
# 24.49489742783178
