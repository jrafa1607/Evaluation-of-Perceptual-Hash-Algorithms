# %%
#https://docs.scipy.org/doc/scipy/reference/spatial.distance.html
from scipy.spatial import *

# %% [markdown]
# <img src="Distances/DistancesCalc.jpg" width="600" height="400">

# %% [markdown]
# <img src="Distances/MinkovskiDistance.jpeg" width="575" height="400">

# %%
#Import Libs
import pandas as pd

# %%
#Path Definition
path = 'D:/Google Drive/Github/Evaluation-of-Perceptual-Hash-Algorithms/Dados/'

# %%
#Database Name Definition
database = 'washingtondatabase'

# %%
#Full Path Definition
full_path = path + database + ".csv"

# %%
#Database Reading
df = pd.read_csv(full_path, delimiter=";", error_bad_lines=False, encoding= 'unicode_escape', engine='python');
# Out:
# C:\Users\Rafael\AppData\Local\Temp\ipykernel_2604\1571487940.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(full_path, delimiter=";", error_bad_lines=False, encoding= 'unicode_escape', engine='python');

# %%
df
# Out:
#             Images Database  A. Hash Hamming  P. Hash Hamming  \
# 0  Fig01_WashingtonDC_Band1                0                0
# 1  Fig02_WashingtonDC_Band2                4                2
# 2  Fig03_WashingtonDC_Band3                2                2
# 3  Fig04_WashingtonDC_Band4               16               16
# 4  Fig05_WashingtonDC_Band5                9               13
# 5  Fig06_WashingtonDC_Band6                5                7
# 6  Fig07_WashingtonDC_Band7                6               11
#
#    D. Hash Hamming  W. Hash Hamming  Hsv-Color Hamming  CP Hash Hamming
# 0                0                0                  0              0.0
# 1                7                2                  0             15.1
# 2                7                2                  0             14.4
# 3               16               16                  1             15.9
# 4               12               11                  1             15.9
# 5                5                6                  1             16.0
# 6                3                7                  1             15.6

# %%
#Select All the Values to the Variables
ahash = df['A. Hash Hamming']
phash = df['P. Hash Hamming']
dhash = df['D. Hash Hamming']
whash = df['W. Hash Hamming']
hsvchash = df['Hsv-Color Hamming']
cphash = df['CP Hash Hamming']

# %%
#Total of Images in Databases

total = int(input("Total of Images in Database: "))
Original_array = []

for i in range(total):
    Original_array.append(0)
# Out:
# Total of Images in Database: 7

# %%
#Function to Calc: Euclidean Distance and Manhattan Distance
def distance_Calc(array,algorithm): 
    dst_euclid = distance.euclidean(Original_array, array)
    dst_manh = distance.cityblock(Original_array, array)
    
    print("\nAlgoritmo: " + str(algorithm))
    print("O Valor da Distância Euclidiana é: " + str(dst_euclid))
    print("O valor da Distância de Manhattan é: " + str(dst_manh))

# %%
#Results for All Distances
distance_Calc(ahash, "Average Hashing")
distance_Calc(phash, "Perceptual Hashing")
distance_Calc(dhash, "Difference Hashing")
distance_Calc(whash, "Wavelet Hashing")
distance_Calc(hsvchash, "HSV-Color Hashing")
distance_Calc(cphash, "Crop-Resistant Hashing")
# Out:
# Algoritmo: Average Hashing
# O Valor da Distância Euclidiana é: 20.445048300260872
# O valor da Distância de Manhattan é: 42
#
# Algoritmo: Perceptual Hashing
# O Valor da Distância Euclidiana é: 24.55605831561735
# O valor da Distância de Manhattan é: 51
#
# Algoritmo: Difference Hashing
# O Valor da Distância Euclidiana é: 23.065125189341593
# O valor da Distância de Manhattan é: 50
#
# Algoritmo: Wavelet Hashing
# O Valor da Distância Euclidiana é: 21.6794833886788
# O valor da Distância de Manhattan é: 44
#
# Algoritmo: HSV-Color Hashing
# O Valor da Distância Euclidiana é: 2.0
# O valor da Distância de Manhattan é: 4
#
# Algoritmo: Crop-Resistant Hashing
# O Valor da Distância Euclidiana é: 37.95194329675359
# O valor da Distância de Manhattan é: 92.89999999999999

# %%
#Example with Minkovski
#1 point = Manhattan; 2 points = Euclidian

dst_mink1= distance.minkowski(Original_array, ahash, 1)
dst_mink2= distance.minkowski(Original_array, ahash, 2)

# %%
#Show the Results
print(dst_mink1)
print(dst_mink2)
# Out:
# 42.0
# 20.445048300260872
