# %%
#https://docs.scipy.org/doc/scipy/reference/spatial.distance.html
from scipy.spatial import *

# %% [markdown]
# <img src="Anexos/DistancesCalc.jpg" width="600" height="400">

# %% [markdown]
# <img src="Anexos/MinkovskiDistance.jpeg" width="575" height="400">

# %%
#Import Libs
import pandas as pd

# %%
#Path Definition
path = 'D:/Google Drive/Github/Evaluation-of-Perceptual-Hash-Algorithms/Dados/'

# %%
#Database Name Definition
database = 'palacedatabase'

# %%
#Full Path Definition
full_path = path + database + ".csv"

# %%
#Database Reading
df = pd.read_csv(full_path, delimiter=";", encoding= 'unicode_escape', engine='python');

# %%
df
# Out:
#      Images Database  A. Hash Hamming  P. Hash Hamming  D. Hash Hamming  \
# 0    Imagem Original                0                0                0
# 1    Alternative (1)                0                0                2
# 2    Alternative (2)                0                0                2
# 3    Alternative (3)                0                0                1
# 4    Alternative (4)                0                0                0
# 5    Alternative (5)                0                0                0
# 6    Alternative (6)                0                0                2
# 7    Alternative (7)                0                0                1
# 8    Alternative (8)                0                0                1
# 9    Alternative (9)                0                0                0
# 10  Alternative (10)                0                0                2
# 11  Alternative (11)                0                0                2
# 12  Alternative (12)                0                0                2
# 13  Alternative (13)                0                0                0
# 14  Alternative (14)                0                2                2
# 15  Alternative (15)                0                0                1
# 16  Alternative (16)                0                0                1
# 17  Alternative (17)               10               10               10
# 18  Alternative (18)               10               11                9
# 19  Alternative (19)               10               10               10
# 20  Alternative (20)               11               11                8
# 21  Alternative (21)               10               10                9
# 22  Alternative (22)               10               10                9
# 23  Alternative (23)               10               10                9
# 24  Alternative (24)                0                0                1
# 25  Alternative (25)                0                0                1
# 26  Alternative (26)                0                0                1
# 27  Alternative (27)                0                0                0
# 28  Alternative (28)                0                0                1
# 29  Alternative (29)                0                0                2
# 30  Alternative (30)                0                0                1
#
#     W. Hash Hamming  Hsv-Color Hamming  CP Hash Hamming
# 0                 0                  0              0.0
# 1                 0                  6             15.4
# 2                 0                  3             15.4
# 3                 0                  4             15.2
# 4                 0                  4             15.4
# 5                 0                  4             15.0
# 6                 0                  4             15.2
# 7                 0                  5             15.4
# 8                 0                  4             15.0
# 9                 0                  3             15.0
# 10                0                  4             15.0
# 11                0                  4             15.0
# 12                0                  4             15.0
# 13                0                  3             15.0
# 14                0                  5             15.2
# 15                0                  4             15.2
# 16                0                  4             15.2
# 17               11                  4             15.4
# 18               11                  2             15.4
# 19               11                  3             14.0
# 20                9                  2             14.8
# 21               11                  4             15.2
# 22               11                  3             15.0
# 23               11                  2             15.2
# 24                0                  4             15.0
# 25                0                  2             15.0
# 26                0                  4             15.0
# 27                0                  4             15.0
# 28                0                  3             15.2
# 29                0                  4             15.0
# 30                0                  3             15.0

# %%
#Select All the Values to the Variables
ahash = df['A. Hash Hamming']
phash = df['P. Hash Hamming']
dhash = df['D. Hash Hamming']
whash = df['W. Hash Hamming']
hsvchash = df['Hsv-Color Hamming']
cphash = df['CP Hash Hamming']

# %%
#Total of Images in Databases

total = int(input("Total of Images in Database (Included the Original): "))
Original_array = []

for i in range(total):
    Original_array.append(0)
# Out:
# Total of Images in Database (Included the Original): 31

# %%
#Function to Calc: Euclidean Distance and Manhattan Distance
def distance_Calc(array,algorithm): 
    dst_euclid = distance.euclidean(Original_array, array)
    dst_manh = distance.cityblock(Original_array, array)
    
    print("\nAlgoritmo: " + str(algorithm))
    print("O Valor da Distância Euclidiana é: " + str(dst_euclid))
    print("O valor da Distância de Manhattan é: " + str(dst_manh))

# %%
#Results for All Distances
distance_Calc(ahash, "Average Hashing")
distance_Calc(phash, "Perceptual Hashing")
distance_Calc(dhash, "Difference Hashing")
distance_Calc(whash, "Wavelet Hashing")
distance_Calc(hsvchash, "HSV-Color Hashing")
distance_Calc(cphash, "Crop-Resistant Hashing")
# Out:
# Algoritmo: Average Hashing
# O Valor da Distância Euclidiana é: 26.851443164195103
# O valor da Distância de Manhattan é: 71
#
# Algoritmo: Perceptual Hashing
# O Valor da Distância Euclidiana é: 27.313000567495326
# O valor da Distância de Manhattan é: 74
#
# Algoritmo: Difference Hashing
# O Valor da Distância Euclidiana é: 25.099800796022265
# O valor da Distância de Manhattan é: 90
#
# Algoritmo: Wavelet Hashing
# O Valor da Distância Euclidiana é: 28.407745422683583
# O valor da Distância de Manhattan é: 75
#
# Algoritmo: HSV-Color Hashing
# O Valor da Distância Euclidiana é: 20.518284528683193
# O valor da Distância de Manhattan é: 109
#
# Algoritmo: Crop-Resistant Hashing
# O Valor da Distância Euclidiana é: 82.68204158098662
# O valor da Distância de Manhattan é: 452.8

# %%
#Example with Minkovski
#1 point = Manhattan; 2 points = Euclidian

dst_mink1= distance.minkowski(Original_array, ahash, 1)
dst_mink2= distance.minkowski(Original_array, ahash, 2)

# %%
#Show the Results
print(dst_mink1)
print(dst_mink2)
# Out:
# 71.0
# 26.851443164195103
