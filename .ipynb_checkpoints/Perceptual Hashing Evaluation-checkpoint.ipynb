# %%
#Evaluation-of-Perceptual-Hash-Algorithms
#Import das Bibliotecas

import os
import cv2
import hashlib
import imagehash
import matplotlib as mpl

from PIL import Image
from scipy.spatial import *
from matplotlib import pyplot as plot

# %%
#Download da Biblioteca para Avaliar algoritmos de Hash Perceptual
#https://pypi.org/project/ImageHash/

# %%
#Path Definition
path = 'D:/Google Drive/Github/Evaluation-of-Perceptual-Hash-Algorithms/ImageDatabase/'

# %%
#Database Name
database = "LennaDatabase"

# %%
#Path Update
path = path + database + "/"

# %%
#Extension Type
ext = ".jpg"

# %%
#Altered Image Definition
image_name = str(input("Altered Image Name: "))
# Out:
# Altered Image Name: lenna-mirror

# %%
#Full Image Name
image_name = image_name + ext
print(image_name)
# Out:
# lenna-mirror.jpg

# %%
#Import Original and Altered Image
original = cv2.imread(path + 'original.jpg')
alterada = cv2.imread(path + image_name)

# %%
#Ordering RGB Layers
original = cv2.cvtColor(original,cv2.COLOR_BGR2RGB)
alterada = cv2.cvtColor(alterada,cv2.COLOR_BGR2RGB)

# %%
#Original Image
plot.imshow(original,cmap='gray')
plot.show()

# %%
#Altered Image
plot.imshow(alterada,cmap='gray')
plot.show()

# %%
#Create a copy of Altered Image to use the Perceptual Hashing
alterada = cv2.cvtColor(alterada,cv2.COLOR_BGR2RGB)
cv2.imwrite(path + 'lenna2.jpg', alterada);

# %% [markdown]
# <b> Conventional Hash Calc: MD5, SHA1 e SHA256 </b>

# %%
#Import of binary files
file1 = path + 'original.jpg'
file2 = path + image_name

# %%
#File Reading
with open(file1, 'rb') as f1:
    data1 = f1.read()
with open(file2, 'rb') as f2:
    data2 = f2.read()

# %%
#Hash Md5, Sha1 and Sha256 Calc
md5_original = str(hashlib.md5(data1).hexdigest())
md5_alterada = str(hashlib.md5(data2).hexdigest())

sha1_original = str(hashlib.sha1(data1).hexdigest())
sha1_alterada = str(hashlib.sha1(data2).hexdigest())

sha256_original = str(hashlib.sha256(data1).hexdigest())
sha256_alterada = str(hashlib.sha256(data2).hexdigest())

# %% [markdown]
# <b> Hamming Distance

# %%
#Hamming Distance Function
def hamming(hash1,hash2):
    L = len(hash1)
    distance = 0
    
    for i in range(L):
        if hash1[i] != hash2[i]:
            distance += 1

    return(str(distance))

# %% [markdown]
# <b> Perceptual Hash - Algorithms</b>
#
# The main Perceptual Hash Types are:
# - Average hashing
# - Perceptual hashing
# - Difference hashing
# - Wavelet hashing
# - HSV color hashing (ColorHash)
# - Crop-resistant hashing

# %%
#Average Hashing
ahash1 = str(imagehash.average_hash(Image.open('ImageDatabase/LennaDatabase/original.jpg')))
ahash2 = str(imagehash.average_hash(Image.open('ImageDatabase/LennaDatabase/lenna2.jpg')))
ahash_dist = hamming(ahash1,ahash2)

# %%
#Perceptual Hashing
phash1 = str(imagehash.phash(Image.open('ImageDatabase/LennaDatabase/original.jpg')))
phash2 = str(imagehash.phash(Image.open('ImageDatabase/LennaDatabase/lenna2.jpg')))
phash_dist = hamming(phash1,phash2)

# %%
#Difference Hashing
dhash1 = str(imagehash.dhash(Image.open('ImageDatabase/LennaDatabase/original.jpg')))
dhash2 = str(imagehash.dhash(Image.open('ImageDatabase/LennaDatabase/lenna2.jpg')))
dhash_dist = hamming(dhash1,dhash2)

# %%
#HSV Color Hashing
hsvhash1 = str(imagehash.colorhash(Image.open('ImageDatabase/LennaDatabase/original.jpg')))
hsvhash2 = str(imagehash.colorhash(Image.open('ImageDatabase/LennaDatabase/lenna2.jpg')))
hsvhash_dist = hamming(hsvhash1,hsvhash2)

# %%
#Wavelet Hashing
whash1 = str(imagehash.whash(Image.open('ImageDatabase/LennaDatabase/original.jpg')))
whash2 = str(imagehash.whash(Image.open('ImageDatabase/LennaDatabase/lenna2.jpg')))
whash_dist = hamming(whash1,whash2)

# %%
#Crop-Resistant Hashing
crhash1 = imagehash.crop_resistant_hash(Image.open('ImageDatabase/LennaDatabase/original.jpg'))
crhash2 = imagehash.crop_resistant_hash(Image.open('ImageDatabase/LennaDatabase/lenna2.jpg'))

ArrayImage01 = str(crhash1).split(',')
ArrayImage02 = str(crhash2).split(',')

if len(ArrayImage01) <= len(ArrayImage02):
    menor = len(ArrayImage01)
    maior = len(ArrayImage02)
    
    total = maior - menor
    for i in range(total):
        ArrayImage01.append('################')
    
elif len(ArrayImage02) < len(ArrayImage01):
    menor = len(ArrayImage02)
    maior = len(ArrayImage01)
    
    total = maior - menor
    for i in range(total):
        ArrayImage02.append('################')

# %% [markdown]
# # Results

# %% [markdown]
# <b> Conventional Hash Calc: MD5, SHA1 e SHA256 </b>

# %%
#Resultados Finais (Arquivos de Hash)
print("\nMD5 Original: " + md5_original)
print("MD5 Alterado: " + md5_alterada)

print("\nSha1 Original: " + sha1_original)
print("Sha1 Alterado: " + sha1_alterada)

print("\nSha256 Original: " + sha256_original)
print("Sha256 Alterado: " + sha256_alterada)
# Out:
# MD5 Original: 0eaf36d4881c513ca70b6684bfaa5b08
# MD5 Alterado: 8d02d1a5b6c958143339e80e172fb473
#
# Sha1 Original: 9a6d6e48b2e5d31eb9e2f38adb877140fa4b1538
# Sha1 Alterado: a4320c15c71e6c7f621eaa506da7b34b24a7979e
#
# Sha256 Original: ebe926ee8951fd5e1282b0945f72c00125c33819a4584dcceb258dbe1c6a1149
# Sha256 Alterado: a0d1c318edcacaf120dc37bb545f83f5d73314b2a92f9f6064ef9d818a9bfe3e

# %% [markdown]
# <b> Perceptual Hash Results </b>

# %%
#Function to Show the results
def show_perceptual(hash_type,hash1,hash2,distance):
    print("\n" + str(hash_type) + " da Imagem Original: " + str(hash1))
    print(str(hash_type) + " da Imagem Alterada: " + str(hash2))
    print("A distância de Hamming Entre a Imagem Original e a Imagem Alterada é: " + str(distance))

# %%
#Resultados Finais (Hash Perceptual)
show_perceptual("Average Hashing",ahash1,ahash2,ahash_dist)
show_perceptual("Perceptual Hashing",phash1,phash2,phash_dist)
show_perceptual("Difference Hashing",dhash1,dhash2,dhash_dist)
show_perceptual("Wavelet Hashing",whash1,whash2,whash_dist)
show_perceptual("HSV Color Hashing",hsvhash1,hsvhash2,hsvhash_dist)
# Out:
# Average Hashing da Imagem Original: b69cbd890b0b8f8c
# Average Hashing da Imagem Alterada: 6d39bd91d0d0f131
# A distância de Hamming Entre a Imagem Original e a Imagem Alterada é: 14
#
# Perceptual Hashing da Imagem Original: 99c6562d7533a296
# Perceptual Hashing da Imagem Alterada: cc9383782866f7c3
# A distância de Hamming Entre a Imagem Original e a Imagem Alterada é: 16
#
# Difference Hashing da Imagem Original: 7670795b33135a38
# Difference Hashing da Imagem Alterada: 91f161253337a5e3
# A distância de Hamming Entre a Imagem Original e a Imagem Alterada é: 14
#
# Wavelet Hashing da Imagem Original: be98bd890b0b8f8c
# Wavelet Hashing da Imagem Alterada: 7d19bd91d0d0f131
# A distância de Hamming Entre a Imagem Original e a Imagem Alterada é: 14
#
# HSV Color Hashing da Imagem Original: 006000c0001
# HSV Color Hashing da Imagem Alterada: 006000c0001
# A distância de Hamming Entre a Imagem Original e a Imagem Alterada é: 0

# %% [markdown]
# <b> Exibição dos Resultados do Hash Perceptual - Crop Resistance Hashing </b>

# %%
#Function to show the Results about Crop-Resistance Hashing
total = 0
for i in range(maior):
    print("Crop-Resistant Hashing da Imagem Original: " + str(i + 1) + "ª Redução: " + str(ArrayImage01[i]))
    print("Crop-Resistant Hashing da Imagem Alterada: " + str(i + 1) + "ª Redução: " + str(ArrayImage02[i]))
    
    distance = 0
    string1 = ArrayImage01[i]
    string2 = ArrayImage02[i]
    
    for n in range(len(string1)):        
        if string1[n] != string2[n]:
            distance += 1
    
    total = total + distance
    print("A Distância de Hamming do Crop-Resistant Hashing é: " + str(distance))
    print("\n")

print("O total das 8 Distancias de Hamming do Crop-Resistance é: " + str(total))
print("Dividido por 8: " + str(total/8))
# Out:
# Crop-Resistant Hashing da Imagem Original: 1ª Redução: 1838bc3c3c3cd8cc
# Crop-Resistant Hashing da Imagem Alterada: 1ª Redução: cc5870b1101991a1
# A Distância de Hamming do Crop-Resistant Hashing é: 15
#
#
# Crop-Resistant Hashing da Imagem Original: 2ª Redução: cce5f172e767767a
# Crop-Resistant Hashing da Imagem Alterada: 2ª Redução: c7e3c0c3c3c3e4cc
# A Distância de Hamming do Crop-Resistant Hashing é: 14
#
#
# Crop-Resistant Hashing da Imagem Original: 3ª Redução: 67c6808082e23019
# Crop-Resistant Hashing da Imagem Alterada: 3ª Redução: 191cfefebeb8f366
# A Distância de Hamming do Crop-Resistant Hashing é: 16
#
#
# Crop-Resistant Hashing da Imagem Original: 4ª Redução: eede5bc79e67676f
# Crop-Resistant Hashing da Imagem Alterada: 4ª Redução: e4721bcf673391ca
# A Distância de Hamming do Crop-Resistant Hashing é: 13
#
#
# Crop-Resistant Hashing da Imagem Original: 5ª Redução: 016558c4f1f9f4fe
# Crop-Resistant Hashing da Imagem Alterada: 5ª Redução: 7959e45c7060c080
# A Distância de Hamming do Crop-Resistant Hashing é: 16
#
#
# Crop-Resistant Hashing da Imagem Original: 6ª Redução: d8b1270c193376ac
# Crop-Resistant Hashing da Imagem Alterada: 6ª Redução: 8884251c86191909
# A Distância de Hamming do Crop-Resistant Hashing é: 13
#
#
# Crop-Resistant Hashing da Imagem Original: 7ª Redução: 07370f07071fe3f1
# Crop-Resistant Hashing da Imagem Alterada: 7ª Redução: 1f10061e1d073870
# A Distância de Hamming do Crop-Resistant Hashing é: 15
#
#
# Crop-Resistant Hashing da Imagem Original: 8ª Redução: 6c999932f2362644
# Crop-Resistant Hashing da Imagem Alterada: 8ª Redução: c96666b3b0939bdd
# A Distância de Hamming do Crop-Resistant Hashing é: 16
#
#
# O total das 8 Distancias de Hamming do Crop-Resistance é: 118
# Dividido por 8: 14.75
