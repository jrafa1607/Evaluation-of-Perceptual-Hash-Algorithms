# %%
#Import Libs
import os
import csv
import cv2
import hashlib
import imagehash
import pandas as pd

from PIL import Image
from scipy.spatial import *
from matplotlib import pyplot as plot

# %%
#Download da Biblioteca para Avaliar algoritmos de Hash Perceptual
#https://pypi.org/project/ImageHash/

# %%
#Warning Fix
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
#Path Definition
path = 'D:/Google Drive/Github/Evaluation-of-Perceptual-Hash-Algorithms/Image Database/'

# %%
#Dabatase Definition
database = 'LennaDatabase'

# %%
#All the Databases
'''
LennaDatabase'
MountainDatabase'
PalaceDatabase'
ParkDatabase'
Washington Database'
''';

# %%
#Path Full Definition
path = path + database + "/"
print(path)
# Out:
# D:/Google Drive/Github/Evaluation-of-Perceptual-Hash-Algorithms/Image Database/LennaDatabase/

# %%
#Image Name (Altered) and Original Definition
image_original_name = str(input("Original Image Name (With Extension): "));
image_name = str(input("Altered Image Name (With Extension): "));
# Out:
# Original Image Name (With Extension): Original.jpg
# Altered Image Name (With Extension): bordas-enfatizadas.jpg

# %%
#Full Name Definition
img_original = str(path + image_original_name)
img_alterada = str(path + image_name)

print(img_original)
print(img_alterada)
# Out:
# D:/Google Drive/Github/Evaluation-of-Perceptual-Hash-Algorithms/Image Database/LennaDatabase/Original.jpg
# D:/Google Drive/Github/Evaluation-of-Perceptual-Hash-Algorithms/Image Database/LennaDatabase/bordas-enfatizadas.jpg

# %%
#Import the Original and Altered Images
original = cv2.imread(img_original)
alterada = cv2.imread(img_alterada)

# %%
#Ordering RGB Layers
original = cv2.cvtColor(original,cv2.COLOR_BGR2RGB)
alterada = cv2.cvtColor(alterada,cv2.COLOR_BGR2RGB)

# %%
#Original Image
plot.imshow(original,cmap='gray')
plot.title('Original Image')
plot.show()

#Altered Image
plot.imshow(alterada,cmap='gray')
plot.title('Altered Image')
plot.show()

# %%
#Create a copy of Altered Image to use the Perceptual Hashing
alterada = cv2.cvtColor(alterada,cv2.COLOR_BGR2RGB)
cv2.imwrite(path + 'img2.jpg', alterada);

# %% [markdown]
# <b> Hamming Distance

# %%
#Hamming Distance Function
def hamming(hash1,hash2):
    L = len(hash1)
    distance = 0
    
    for i in range(L):
        if hash1[i] != hash2[i]:
            distance += 1

    return(str(distance))

# %% [markdown]
# <b> Conventional Hash Experiment </b>
# - MD5
# - SHA1
# - SHA256

# %%
#Import of binary files
file1 = path + image_original_name
file2 = path + image_name

# %%
#File Reading
with open(file1, 'rb') as f1:
    data1 = f1.read()
with open(file2, 'rb') as f2:
    data2 = f2.read()

# %%
#Hash Md5, Sha1 and Sha256 Calc
md5_original = str(hashlib.md5(data1).hexdigest())
md5_alterada = str(hashlib.md5(data2).hexdigest())

sha1_original = str(hashlib.sha1(data1).hexdigest())
sha1_alterada = str(hashlib.sha1(data2).hexdigest())

sha256_original = str(hashlib.sha256(data1).hexdigest())
sha256_alterada = str(hashlib.sha256(data2).hexdigest())

# %% [markdown]
# <b> Perceptual Hash Experiment</b>
# - Average hashing
# - Perceptual hashing
# - Difference hashing
# - Wavelet hashing
# - HSV color hashing (ColorHash)
# - Crop-resistant hashing

# %%
#Average Hashing
ahash1 = str(imagehash.average_hash(Image.open(file1)))
ahash2 = str(imagehash.average_hash(Image.open(file2)))
ahash_dist = hamming(ahash1,ahash2)

# %%
#Perceptual Hashing
phash1 = str(imagehash.phash(Image.open(file1)))
phash2 = str(imagehash.phash(Image.open(file2)))
phash_dist = hamming(phash1,phash2)

# %%
#Difference Hashing
dhash1 = str(imagehash.dhash(Image.open(file1)))
dhash2 = str(imagehash.dhash(Image.open(file2)))
dhash_dist = hamming(dhash1,dhash2)

# %%
#HSV Color Hashing
hsvhash1 = str(imagehash.colorhash(Image.open(file1)))
hsvhash2 = str(imagehash.colorhash(Image.open(file2)))
hsvhash_dist = hamming(hsvhash1,hsvhash2)

# %%
#Wavelet Hashing
whash1 = str(imagehash.whash(Image.open(file1)))
whash2 = str(imagehash.whash(Image.open(file2)))
whash_dist = hamming(whash1,whash2)

# %%
#Crop-Resistant Hashing
crhash1 = imagehash.crop_resistant_hash(Image.open(file1))
crhash2 = imagehash.crop_resistant_hash(Image.open(file2))

ArrayImage01 = str(crhash1).split(',')
ArrayImage02 = str(crhash2).split(',')

if len(ArrayImage01) <= len(ArrayImage02):
    menor = len(ArrayImage01)
    maior = len(ArrayImage02)
    
    total = maior - menor
    for i in range(total):
        ArrayImage01.append('################')
    
elif len(ArrayImage02) < len(ArrayImage01):
    menor = len(ArrayImage02)
    maior = len(ArrayImage01)
    
    total = maior - menor
    for i in range(total):
        ArrayImage02.append('################')

# %%
#Function to show the Results about Crop-Resistance Hashing Hamming Distance
total = 0
for i in range(maior):
    
    distance = 0
    string1 = ArrayImage01[i]
    string2 = ArrayImage02[i]
    
    for n in range(len(string1)):        
        if string1[n] != string2[n]:
            distance += 1
    
    total = total + distance
media = total / maior

print("Total of Reductions: " + str(maior) + " with the Original File")
print("Sum of Hamming Distances: " + str(total))
print("Mean Hamming Distances: " + str(media))
# Out:
# Total of Reductions: 8 with the Original File
# Sum of Hamming Distances: 96
# Mean Hamming Distances: 12.0

# %% [markdown]
# # Results
#
# In this steps, All the results are inputed in the Dataframes.
# The Dataframes are:
# - df0: Image and Database Names
# - df1: Conventional Hash
# - df2: Perceptual Hash
# - df3: Crop-Resistance Hash
# - df4: All Hamming Distance Values

# %%
#Ajust the Dataframe to Show all Information Value
pd.set_option('display.max_colwidth', None)
pd.set_option('display.expand_frame_repr', False)

# %%
#Create Dataframes to Show All results
df0 = pd.DataFrame(columns=('ImageName', 'Database'))
df1 = pd.DataFrame(columns=('MD5', 'SHA1', 'SHA256'))
df2 = pd.DataFrame(columns=('Ahash', 'Phash', 'Dhash', 'Whash', 'Hsv-Chash'))
df3 = pd.DataFrame()

for i in range(maior):
    colname = "CPR Hash 0" + str(i + 1)
    df3[colname] = colname
    
df4 = pd.DataFrame(columns=('Hamming Distance', 'Ahash', 'Phash', 'Dhash', 'Whash', 'Hsv-Chash', 'CPRhash'))

# %%
#Attach the Values - Image Names
values_hash1 = {'ImageName': "Original", 'Database': database};
values_hash2 = {'ImageName': image_name, 'Database': database};

df0 = df0.append(values_hash1, ignore_index = True);
df0 = df0.append(values_hash2, ignore_index = True);

# %%
#Attach the Values - Conventional Hash
values_hash1 = {'MD5': md5_original, 'SHA1': sha1_original, 'SHA256': sha256_original};
values_hash2 = {'MD5': md5_alterada, 'SHA1': sha1_alterada, 'SHA256': sha256_alterada};

df1 = df1.append(values_hash1, ignore_index = True);
df1 = df1.append(values_hash2, ignore_index = True);

# %%
#Attach the Values - Perceptual Hash
values_hash1 = {'Ahash': ahash1, 'Phash': phash1, 'Dhash': dhash1, 'Whash': whash1, 'Hsv-Chash': hsvhash1};
values_hash2 = {'Ahash': ahash2, 'Phash': phash2, 'Dhash': dhash2, 'Whash': whash2, 'Hsv-Chash': hsvhash2};

df2 = df2.append(values_hash1, ignore_index = True);
df2 = df2.append(values_hash2, ignore_index = True);

# %%
#Attach the Values - Crop-Resistance Hash
for i in range(maior):
    colname = "CPR Hash 0" + str(i + 1)
    df3.at[0, colname] = ArrayImage01[i]
    df3.at[1, colname] = ArrayImage02[i]

# %%
#Attach the Values - Hamming Distance
values_hash1 = {'Hamming Distance': 'Original','Ahash': 0, 'Phash': 0, 'Dhash': 0, 'Whash': 0, 'Hsv-Chash': 0, 'CPRhash': 0};
values_hash2 = {'Hamming Distance': image_name,'Ahash': ahash_dist, 'Phash': phash_dist, 'Dhash': dhash_dist, 'Whash': whash_dist, 'Hsv-Chash': hsvhash_dist, 'CPRhash': media};

df4 = df4.append(values_hash1, ignore_index = True);
df4 = df4.append(values_hash2, ignore_index = True);

# %%
#Concat all the Dataframes
df = pd.concat([df0, df1, df2, df3, df4], axis = 1)

# %%
#Show the Dataframe with All Results
df
# Out:
#                 ImageName       Database                               MD5                                      SHA1                                                            SHA256             Ahash             Phash             Dhash             Whash    Hsv-Chash  ...       CPR Hash 06       CPR Hash 07       CPR Hash 08        Hamming Distance Ahash Phash Dhash Whash Hsv-Chash CPRhash
# 0                Original  LennaDatabase  0eaf36d4881c513ca70b6684bfaa5b08  9a6d6e48b2e5d31eb9e2f38adb877140fa4b1538  ebe926ee8951fd5e1282b0945f72c00125c33819a4584dcceb258dbe1c6a1149  b69cbd890b0b8f8c  99c6562d7533a296  7670795b33135a38  be98bd890b0b8f8c  006000c0001  ...  d8b1270c193376ac  07370f07071fe3f1  6c999932f2362644                Original     0     0     0     0         0       0
# 1  bordas-enfatizadas.jpg  LennaDatabase  24aa3d32857e78a83e8445c50ac5efce  a8a8486d44ac4bae115038bd41558edb4c8d7623  6e8099909ea66726cb3779ab3ff0902582ae749993af68a5e9d710fe9f5956bc  b69cbd890b0b8f8c  99c6562d7533a296  6470795b33135a38  be98bd890b0b8f8c  014000c0001  ...  07e78703031fe3f1  ac999932d2362644  ################  bordas-enfatizadas.jpg     0     0     2     0         2    12.0
#
# [2 rows x 25 columns]

# %%
#Export Dataframe to .csv File
df.to_csv('Export.csv', encoding='utf-8', index=False, mode='a', header=False)
